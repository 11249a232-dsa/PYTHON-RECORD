# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a232-dsa/PYTHON-RECORD/blob/main/exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Aim = "Find Palindrome and Character Frequency"
print(Aim)
input_str = input("Enter a string: ")
if input_str == input_str[::-1]:
  print("Palindrome")
else:
  print("Not Palindrome")
for ch in set(input_str):
  count = input_str.count(ch)
  print(f"'{ch}' appears {count} times")
# Out:
# Find Palindrome and Character Frequency
# Enter a string: likith
# Not Palindrome
# 'i' appears 2 times
# 'k' appears 1 times
# 'l' appears 1 times
# 't' appears 1 times
# 'h' appears 1 times
