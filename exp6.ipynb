# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a232-dsa/PYTHON-RECORD/blob/main/exp6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Aim = "Sentence Statistics: Write a Python program that accepts a sentence and find the number of words, digits, uppercase l"
print(Aim)
sentence = input("Enter a sentence: ")
# Count words
words = sentence.split()
num_words = len(words)
# Initialize counters
num_digits = 0
num_uppercase = 0
num_lowercase = 0
# Count digits and letters
for char in sentence:
    if char.isdigit():
        num_digits += 1
    elif char.isupper():
        num_uppercase += 1
    elif char.islower():
        num_lowercase += 1
print("Number of words:", num_words)
print("Number of digits:", num_digits)
print("Number of uppercase letters:", num_uppercase)
print("Number of lowercase letters:", num_lowercase)
# Out:
# Sentence Statistics: Write a Python program that accepts a sentence and find the number of words, digits, uppercase l
# Enter a sentence: Today we have a wonderful day with prasad by playing volleyball
# Number of words: 11
# Number of digits: 0
# Number of uppercase letters: 1
# Number of lowercase letters: 52
